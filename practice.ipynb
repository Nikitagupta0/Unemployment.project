# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Unemployment in India.csv",parse_dates=[' Date'])

# %%
data.head()
# Out:
#            Region       Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31    Monthly                              3.65
# 1  Andhra Pradesh 2019-06-30    Monthly                              3.05
# 2  Andhra Pradesh 2019-07-31    Monthly                              3.75
# 3  Andhra Pradesh 2019-08-31    Monthly                              3.32
# 4  Andhra Pradesh 2019-09-30    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
data
# Out:
#              Region       Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31    Monthly                              3.65
# 1    Andhra Pradesh 2019-06-30    Monthly                              3.05
# 2    Andhra Pradesh 2019-07-31    Monthly                              3.75
# 3    Andhra Pradesh 2019-08-31    Monthly                              3.32
# 4    Andhra Pradesh 2019-09-30    Monthly                              5.17
# ..              ...        ...        ...                               ...
# 763             NaN        NaT        NaN                               NaN
# 764             NaN        NaT        NaN                               NaN
# 765             NaN        NaT        NaN                               NaN
# 766             NaN        NaT        NaN                               NaN
# 767             NaN        NaT        NaN                               NaN
#
# ...

# %%
print(data.isnull().sum())
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
data.columns = ["States","Date","Frequency",
                "Estimated Unemployment Rate",
                "Estimated Employed",
                "Estimated Labour Participation Rate",
                "Region"]
plt.title("Indian Unemployment")
sns.histplot(x="Estimated Employed",hue="Region",data=data)
plt.show()

# %%
#plt.style.use('seaborn-whitegrid')
#plt.figure(figsize=(8,8))
#sns.heatmap(data.corr())
plt.show()

# %%
data.hist(edgecolor="black",linewidth = 1.2 , figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'Date'}>,
#         <AxesSubplot:title={'center':'Estimated Unemployment Rate'}>],
#        [<AxesSubplot:title={'center':'Estimated Employed'}>,
#         <AxesSubplot:title={'center':'Estimated Labour Participation Rate'}>]],
#       dtype=object)

# %%
d = data.Region.value_counts().head(10)                  # [:10]
plt.figure(figsize=(6,6))
x = list(d.index)
y = list(d.values)
x.reverse()
y.reverse()
plt.title("Estimated Unemployment in Regions")
plt.ylabel("Unemployment Count")
plt.xlabel("Regions")
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
data['States'].value_counts().head(10).plot.pie(autopct = '%.1f%%',
                                                shadow = True,
                                                figsize = (8,8),
                                                startangle = 90,
                                                wedgeprops = {'width': .4},
                                                radius = 1,
                                                pctdistance = .8,
                                                textprops = {'color':"black"})
plt.title('UNEMPLOYMENT RATE IN DIFFERENT STATES', fontsize = '11',color = 'c')
# Out:
# Text(0.5, 1.0, 'UNEMPLOYMENT RATE IN DIFFERENT STATES')

# %%
data['Region'].value_counts().head(10).plot.pie(autopct = '%.1f%%',
                                                shadow = True,
                                                figsize = (8,8),
                                                startangle = 90,
                                                wedgeprops = {'width': .4},
                                                radius = 1,
                                                pctdistance = .8,
                                                textprops = {'color':"black"})
plt.title('REGION WISE', fontsize = '11',color = 'c')
# Out:
# Text(0.5, 1.0, 'REGION WISE')

# %%
data['Date'].value_counts().head(10).plot.pie(autopct = '%.1f%%',
                                                shadow = True,
                                                figsize = (8,8),
                                                startangle = 90,
                                                wedgeprops = {'width': .4},
                                                radius = 1,
                                                pctdistance = .8,
                                                textprops = {'color':"black"})
plt.title('UNEMPLOYMENT RATE IN MONTHS', fontsize = '11',color = 'c')
# Out:
# Text(0.5, 1.0, 'UNEMPLOYMENT RATE IN MONTHS')

# %%
data['Estimated Employed'].value_counts().head(10).plot.pie(autopct = '%.1f%%',
                                                shadow = True,
                                                figsize = (8,8),
                                                startangle = 90,
                                                wedgeprops = {'width': .4},
                                                radius = 1,
                                                pctdistance = .8,
                                                textprops = {'color':"black"})
plt.title('ESTIMATED EMPLOYED', fontsize = '11',color = 'c')
# Out:
# Text(0.5, 1.0, 'ESTIMATED EMPLOYED')

# %%
plt.title("MONTHLY UNEMPLOYEMENT",color='red',fontsize=12)
data['Date'].value_counts().head(10).plot.pie(autopct = '%.1f%%',
                                                figsize = (8,8),
                                                pctdistance = .6,
                                                startangle = 180,
                                                textprops = {'color':"black"})
plt.show()

# %%
data.head()
# Out:
#            States       Date Frequency  Estimated Unemployment Rate  \
# 0  Andhra Pradesh 2019-05-31   Monthly                         3.65
# 1  Andhra Pradesh 2019-06-30   Monthly                         3.05
# 2  Andhra Pradesh 2019-07-31   Monthly                         3.75
# 3  Andhra Pradesh 2019-08-31   Monthly                         3.32
# 4  Andhra Pradesh 2019-09-30   Monthly                         5.17
#
#    Estimated Employed  Estimated Labour Participation Rate Region
# 0          11999139.0                                43.24  Rural
# 1          11755881.0                                42.05  Rural
# 2          12086707.0                                43.50  Rural
# 3          12285693.0                                43.97  Rural
# 4          12256762.0                                44.68  Rural

# %%
data.head(10).plot.line(x="States",y=["Estimated Unemployment Rate","Estimated Labour Participation Rate"],figsize=(10,5),color = 'red')
plt.show()

# %%
clean_cols = [col.strip() for col in data.columns.tolist()]
data.columns = clean_cols
data.columns.tolist()
# Out:
# ['States',
#  'Date',
#  'Frequency',
#  'Estimated Unemployment Rate',
#  'Estimated Employed',
#  'Estimated Labour Participation Rate',
#  'Region']

# %%
data.head(2)
# Out:
#            States       Date Frequency  Estimated Unemployment Rate  \
# 0  Andhra Pradesh 2019-05-31   Monthly                         3.65
# 1  Andhra Pradesh 2019-06-30   Monthly                         3.05
#
#    Estimated Employed  Estimated Labour Participation Rate Region
# 0          11999139.0                                43.24  Rural
# 1          11755881.0                                42.05  Rural

# %%
data.groupby(['Region'])['Estimated Unemployment Rate'].sum().reset_index().sort_values(by='Estimated Unemployment Rate').tail(10).plot(kind='bar',x='Region',figsize=(10,7))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13436/3853572336.py in <module>
# ----> 1 data.groupby(['Region'])['Estimated Unemployment Rate'].sum().reset_index().sort_values(by='Estimated Unemployment Rate').tail(10).plot(kind='pie',x='Region',figsize=(10,7))
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     921             if isinstance(data, ABCDataFrame):
#     922                 if y is None and kwargs.get("subplots") is False:
# --> 923                     raise ValueError(
#     924                         f"{kind} requires either y column or 'subplots=True'"
#     925                     )
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
data.Region.unique()
# Out:
# array(['Rural', nan, 'Urban'], dtype=object)

# %%
data[data['Region']=='States'].set_index('Date')['Estimated Unemployment Rate']
# Out:
# Series([], Name: Estimated Unemployment Rate, dtype: float64)
